# %%
#sinc function
import matplotlib.pyplot as plt
import math
import numpy as np
import scipy.stats as stats
x = np.linspace(-5, 5, 400) 

for kkk in range(10):
    y_list = []
    y_list.append((np.sin(kkk*x)/x))#Write the function I want.

y = sum(y_list)

plt.plot(x,y, color='#000000')
plt.show()
